# %%
from pyg2plot import Plot

line = Plot("Line")

line.set_options({
  "height": 400, # set a default height in jupyter preview
  "data": [
    { "year": "1991", "value": 3 },
    { "year": "1992", "value": 4 },
    { "year": "1993", "value": 3.5 },
    { "year": "1994", "value": 5 },
    { "year": "1995", "value": 4.9 },
    { "year": "1996", "value": 6 },
    { "year": "1997", "value": 7 },
    { "year": "1998", "value": 9 },
    { "year": "1999", "value": 13 },
  ],
  "xField": "year",
  "yField": "value",
})

line.render_jupyter_lab()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <meta charset="UTF-8">
#   <title>PyG2Plot</title>
# </head>
# <body>
#   <style>
#     * {
#       margin: 0;
#       padding: 0;
#       box-sizing: border-box;
#     }
#     html, body, div.pyg2plot-plot-container {
#       height: 100%;
#       overflow: hidden;
#     }
#   </style>
#
#   <div id="bc6ad77b7bef42bdb7bca26aca4df65a" class="pyg2plot-plot-container"></div>
#
#   <script>
#     // load javascript
#     new Promise(function(resolve, reject) {
#       var script = document.createElement("script");
#       script.onload = resolve;
#       script.onerror = reject;
#       script.src = "https://unpkg.com/@antv/g2plot@2";
#       document.head.appendChild(script);
#     }).then(() => {
#       var plot_bc6ad77b7bef42bdb7bca26aca4df65a = new G2Plot.Line("bc6ad77b7bef42bdb7bca26aca4df65a", {
#   "height": 400,
#   "data": [
#     {
#       "year": "1991",
#       "value": 3
#     },
#     {
#       "year": "1992",
#       "value": 4
# ...
